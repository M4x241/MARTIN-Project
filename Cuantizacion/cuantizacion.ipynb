# %%
import tensorflow as tf
import numpy as np

# Cargar modelo entrenado
model = tf.keras.models.load_model("/home/ghost/Documents/6toSemestre/MARTIN-Project/robot_model.h5")

# Datos representativos para cuantizar
# Deben ser muestras reales de sensores (L, C, R)
def representative_dataset():
    for _ in range(200):
        sample = np.random.uniform(5, 100, size=(3,))  # ejemplo: distancias 5–100 cm
        yield [sample.astype(np.float32).reshape(1, 3)]

# Convertidor TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset

# Hacer que la entrada y salida sean INT8
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_quant_model = converter.convert()

with open("robot_quant.tflite", "wb") as f:
    f.write(tflite_quant_model)

print("Modelo cuantizado guardado como robot_quant.tflite")
# Out:
# 2025-11-14 08:09:56.692203: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-14 08:09:56.741900: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-14 08:09:58.307635: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-14 08:09:58.814293: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
# ...
